# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

songs = pd.read_csv('C:/Users/user/Desktop/FYP/harmonicai/backend/database/spotify_songs.csv')
songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
# Define the linear transformation function
def convert_popularity_to_listens(popularity, old_min=0, old_max=100, new_min=0, new_max=32800):
    return ((popularity - old_min) / (old_max - old_min)) * (new_max - new_min) + new_min

# Apply the transformation to the 'track_popularity' column
songs['listen_count'] = songs['track_popularity'].apply(convert_popularity_to_listens).astype(int)

# Display the first few rows to verify the transformation
songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     track_album_name track_album_release_date  \
# ...

# %%
# Drop unneccessary columns
songs = songs.drop(columns=['track_popularity', 'track_album_id', 'track_album_name', 'track_album_release_date', 'playlist_name', 'playlist_id', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 
            'instrumentalness', 'liveness', 'valence', 'tempo'])
songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist playlist_genre playlist_subgenre  duration_ms  \
# 0        Ed Sheeran            pop         dance pop       194754
# 1          Maroon 5            pop         dance pop       162600
# 2      Zara Larsson            pop         dance pop       176616
# 3  The Chainsmokers            pop         dance pop       169093
# 4     Lewis Capaldi            pop         dance pop       189052
#
#    listen_count
# 0         21648
# 1         21976
# 2         22960
# 3         19680
# 4         22632

# %%
# Function to convert milliseconds to MM:SS format
def convert_ms_to_mmss(duration_ms):
    seconds = duration_ms // 1000
    minutes = seconds // 60
    seconds = seconds % 60
    return f"{minutes:02}:{seconds:02}"

# Apply the function to convert duration_ms to MM:SS format
songs['duration'] = songs['duration_ms'].apply(convert_ms_to_mmss)
songs = songs.drop(columns=['duration_ms'])

songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist playlist_genre playlist_subgenre  listen_count duration
# 0        Ed Sheeran            pop         dance pop         21648    03:14
# 1          Maroon 5            pop         dance pop         21976    02:42
# 2      Zara Larsson            pop         dance pop         22960    02:56
# 3  The Chainsmokers            pop         dance pop         19680    02:49
# 4     Lewis Capaldi            pop         dance pop         22632    03:09

# %%
songs['genre'] = songs['playlist_genre'] + ' ' + songs['playlist_subgenre']
songs = songs.drop(columns=['playlist_genre', 'playlist_subgenre'])
songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        track_artist  listen_count duration          genre
# 0        Ed Sheeran         21648    03:14  pop dance pop
# 1          Maroon 5         21976    02:42  pop dance pop
# 2      Zara Larsson         22960    02:56  pop dance pop
# 3  The Chainsmokers         19680    02:49  pop dance pop
# 4     Lewis Capaldi         22632    03:09  pop dance pop

# %%
# Store the new DataFrame in cleaned_spotify_songs.csv
songs.to_csv('C:/Users/user/Desktop/FYP/harmonicai/backend/database/cleaned_spotify_songs.csv', index=False)

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   track_id      32833 non-null  object
#  1   track_name    32828 non-null  object
#  2   track_artist  32828 non-null  object
#  3   listen_count  32833 non-null  int32
#  4   duration      32833 non-null  object
#  5   genre         32833 non-null  object
# dtypes: int32(1), object(5)
# memory usage: 1.4+ MB

# %%
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import pandas as pd
import numpy as np
import re
import gensim.downloader as api
from gensim.parsing.preprocessing import remove_stopwords

songs = pd.read_csv('C:/Users/user/Desktop/FYP/harmonicai/backend/database/cleaned_spotify_songs.csv')
songs['track_name'] = songs['track_name'].astype(str)
song_names = songs['track_name']

# Load model
model = api.load('word2vec-google-news-300')

# Preprocess the sentences
song_names = [remove_stopwords(song.lower()).split() for song in song_names]


def sentence_vector(sentence, model):
    words = [word for word in sentence if word in model]
    if not words:
        return np.zeros(model.vector_size)
    return np.mean([model[word] for word in words], axis=0)


song_vectors = np.array([sentence_vector(song, model) for song in song_names])

# Save vector to a file
np.save('C:/Users/user/Desktop/FYP/harmonicai/backend/database/song_vector.npy', song_vectors)

# %%
song_vectors[:5]
# Out:
# array([[ 0.06123861, -0.00130208,  0.05737305, ..., -0.13525391,
#          0.04286702, -0.0024821 ],
#        [ 0.00109863,  0.08121745,  0.15795898, ..., -0.25553384,
#          0.04541016,  0.08927409],
#        [ 0.00328573, -0.00980632,  0.11435954, ..., -0.14115906,
#          0.03548177,  0.11149088],
#        [-0.05187988, -0.08032227,  0.20019531, ..., -0.17138672,
#         -0.05493164,  0.14916992],
#        [ 0.06439209, -0.09603882,  0.04516602, ..., -0.16882324,
#          0.08105469, -0.05541992]])

# %%
genres = songs['genre']
genres = [remove_stopwords(genre.lower()).split() for genre in genres]
genres_vectors = np.array([sentence_vector(genre, model) for genre in genres])

# Save vector to a file
np.save('C:/Users/user/Desktop/FYP/harmonicai/backend/database/genres_vector.npy', genres_vectors)

# %%
artists = songs['track_artist'].astype(str)
artists = [remove_stopwords(artist.lower()).split() for artist in artists]
artists_vectors = np.array([sentence_vector(artist, model) for artist in artists])

# Save vector to a file
np.save('C:/Users/user/Desktop/FYP/harmonicai/backend/database/artists_vector.npy', artists_vectors)
